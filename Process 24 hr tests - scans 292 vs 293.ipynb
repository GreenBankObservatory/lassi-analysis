# %%
# %matplotlib notebook
from lassiAnalysis import processLeicaScan, processLeicaScanPair
file1 = "292_2019-06-12_05:01:04.ptx"
file2 = "293_2019-06-12_05:04:18.ptx"
fpath = "/home/scratch/pmargani/LASSI/scannerData/"
import os
fn1 = os.path.join(fpath, file1)
fn2 = os.path.join(fpath, file2)
rot = -10.

# %%
# %%time
xy, diff = processLeicaScanPair(fn1, fn2, rFilter=True, rot=rot, fitZernikies=False)
# Out:
# Processing PTX file ...
# ProcessNewPTXData with:  -8.0 50.0 -10.0 47.0
# Picking 10000 random data points from a total of 8430887
# Skipped 0 non-data lines
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# Skipped 0 non-data lines
# Starting with 8430887 lines of data
# Filtered out 0 points of 8430887 ( 0.00%) intensity equal to zero
# Now we have 8430887 lines of data
# neighborFilter reduces 8430887 points to 8201274 points (229613 filtered, 2.723474 %) using tol: 0.122000
# Now we have 8201274 lines of data
# Intensity: max= 1.00, min= 0.00, mean= 0.66, std= 0.14
# radial limit filtered out 1658545 points outside radius 47.00
# Now we have 6542729 lines of data
# z - limit filtered out 7433 points below -80.00
# Rotating about Z by -10.00 degrees
# Now we have 6535296 lines of data
# <img src="data:image/png;base64,..." width="640">
# ...
