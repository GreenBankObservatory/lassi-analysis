# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pylab as plt

from astropy.io import fits

import sys
sys.path.append('/home/scratch/psalas/LASSI/lassi-analysis_v2')
from plotting import scatter3dPlot
from processPTX import previewEllipticalFilter

# %%
def load_lassi_fits(filename):
    
    hdu = fits.open(filename)
    data = hdu[1].data
    x = data['X']
    y = data['Y']
    z = data['Z']
    i = data['INTENSIT']
    d = data['DMJD']
    
    return x,y,z,i,d

def fits_to_csv(filename, output):
    
    x, y, z, i, d = load_lassi_fits(filename)
    np.savetxt(output, np.c_[x, y, z, i], delimiter=' ')

# %%
sample = 0.1 # Only plot 10% of the data.
fitsFile = '/home/gbtdata/TLASSI_200315/LASSI/2020_03_16_05:22:24.fits'

# %%
x,y,z,i,d = load_lassi_fits(fitsFile)
scatter3dPlot(x, y, z, "preview", sample=sample)
# Out:
# Plotting  0.10 percent of data
# Now length of data is 18568
# <img src="data:image/png;base64,..." width="640">

# %%
ellipse = [-44, -5.5, 50, 50, 0]
outputdir = "/home/scratch/psalas/LASSI/15Mar"
ptxFile = '{0}/2020_03_16_05:22:24.ptx'.format(outputdir)
previewEllipticalFilter(ptxFile, ellipse)
# Out:
# Opening PTX file /home/scratch/psalas/LASSI/15Mar/2020_03_16_05:22:24.ptx
# Picking 10000 random data points from a total of 18568119
# Skipped 0 non-data lines
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
outputdir = "/home/scratch/psalas/LASSI/15Mar"
ptxFile = '{0}/2020_03_16_00:35:21.ptx'.format(outputdir)
fits_to_csv(fitsFile, ptxFile)

# %%
ellipse = [-42, -6., 48, 48, 0]
previewEllipticalFilter(ptxFile, ellipse)
# Out:
# Opening PTX file /home/scratch/psalas/LASSI/15Mar/2020_03_16_00:35:21.ptx
# Picking 10000 random data points from a total of 18562865
# Skipped 0 non-data lines
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
sample = 0.1
fitsFile = '/home/gbtdata/TLASSI_200315/LASSI/2020_03_16_10:50:32.fits'
x,y,z,i,d = load_lassi_fits(fitsFile)
scatter3dPlot(x, y, z, "preview", sample=sample)
# Out:
# Plotting  0.10 percent of data
# Now length of data is 30053
# <img src="data:image/png;base64,..." width="640">
