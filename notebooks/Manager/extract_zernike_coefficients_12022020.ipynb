# %% [markdown]
# How do we go from a .ptx file to Zernike coefficients?

# %%
# Set up notebook
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
import glob
import numpy as np
import pylab as plt

# Make sure we can find lassi-analysis
import sys
sys.path.append('/home/scratch/psalas/LASSI/lassi-analysis_v2')

# Load lassi-analysis modules
from plotting import barChartPlot, surfacePlot
from lassiAnalysis import processLeicaScan, extractZernikesLeicaScanPair

# %%
# Parameters for processing (segmenting and smoothing) the raw PTX data.
n = 512
xOffset = -44; yOffset=-6.5; rot=80.; radius=49.
path = "/export/simdata/TINT_200212"

# %%
# Extract Zernike coefficients from the signal minus reference.
# Notice that the input is the output from gpus.smoothGPUs, i.e. the .csv files.
ref_file = '/home/scratch/psalas/LASSI/gpus/output/Feb20tests/2020_02_12_13:51:55.csv'
sig_file = '/home/scratch/psalas/LASSI/gpus/output/Feb20tests/2020_02_12_14:02:19.csv'
x, y, diff, fitlist = extractZernikesLeicaScanPair(ref_file, sig_file)
# Out:
# Masking file: /home/scratch/psalas/LASSI/gpus/output/Feb20tests/2020_02_12_13:51:55.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-f3b24c1d0496> in <module>
#       3 ref_file = '/home/scratch/psalas/LASSI/gpus/output/Feb20tests/2020_02_12_13:51:55.csv'
#       4 sig_file = '/home/scratch/psalas/LASSI/gpus/output/Feb20tests/2020_02_12_14:02:19.csv'
# ----> 5 x, y, diff, fitlist = extractZernikesLeicaScanPair(ref_file, sig_file)
#
# /home/scratch/psalas/LASSI/lassi-analysis_v2/lassiAnalysis.py in extractZernikesLeicaScanPair(refScanFile, sigScanFile, n, nZern, pFitGuess, rMaskRadius)
#     187
#     188     print('Masking file: {}'.format(refScanFile))
# --> 189     ref_data = maskLeicaData(refScanFile, n=n, guess=pFitGuess, radialMask=radialMask, maskRadius=rMaskRadius)
#     190
#     191     # Extract the data we will use.
#
# /home/scratch/psalas/LASSI/lassi-analysis_v2/lassiAnalysis.py in maskLeicaData(filename, n, guess, bounds, radialMask, maskRadius, **kwargs)
#     460     """
#     461
# --> 462     orgData, cleanData = loadLeicaData(filename, n=n, numpy=False)
#     463
#     464     xf = orgData[0]
#
# /home/scratch/psalas/LASSI/lassi-analysis_v2/parabolas.py in loadLeicaData(fn, n, numpy)
#     402         xx, yy, zz = flatData
#     403     else:
# --> 404         xx, yy, zz = loadLeicaDataFromGpus(fn)
#     405         x = copy(xx)
#     406         y = copy(yy)
#
# /home/scratch/psalas/LASSI/lassi-analysis_v2/parabolas.py in loadLeicaDataFromGpus(fn)
#     380         data = []
#     381         fnn = "%s.%s.csv" % (fn, dim)
# --> 382         with open(fnn, 'r') as f:
#     383             ls = f.readlines()
#     384         for l in ls:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/scratch/psalas/LASSI/gpus/output/Feb20tests/2020_02_12_13:51:55.csv.x.csv'

# %%
# What are we expecting?
# Based on the active surface fits file.
expected = np.zeros(37)
expected[13] = 594.
# Plot a bar chart with the recovered and expected values.
barChartPlot(np.arange(1,36), np.asarray(fitlist[1:36])*1e6, expected=expected[1:36])
# Show the surface deformation map.
surfacePlot(x, y, diff, vMin=-5e-3, vMax=5e-3)
# Out:
# <img src="data:image/png;base64,..." width="720">
# <img src="data:image/png;base64,..." width="750">

# %%
700./np.sqrt()
