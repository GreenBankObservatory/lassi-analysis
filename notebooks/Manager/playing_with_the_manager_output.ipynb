# %%
# %matplotlib notebook

# %%
import numpy as np
import pylab as plt

from astropy.io import fits

# %%
datadir = "/export/simdata/TINT_3"

# %%
hdu = fits.open("{0}/ScanLog.fits".format(datadir))

# %%
head = hdu[0].header

# %%
head
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                    8 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# ORIGIN  = 'NRAO Green Bank'    /
# INSTRUME= 'ScanLog '           / device or program of origin
# GBTMCVER= 'lassi   '           / telescope control software release
# FITSVER = '2.1     '           / FITS definition version for this device
# DATEBLD = '2019-12-09T20:00:20' / time program was linked
# SIMULATE=                    0 / Is the instrument in simulate mode?
# TELESCOP= 'NRAO_GBT'           / Green Bank Telescope (Robert C. Byrd 100m)
# PROJID  = 'TINT_3  '           / Manager parameter projectId

# %%
data = hdu[1].data

# %%
data
# Out:
# FITS_rec([('2020-02-03T19:38:20',  85, './TINT_3/ActiveSurfaceMgr/2020_02_03_19:38:20.fits'),
#           ('2020-02-03T19:38:20',  85, 'SCAN STARTING AT 58882 19:38:23'),
#           ('2020-02-03T19:38:20',  85, 'SCAN FINISHED AT 58882 19:38:27'),
#           ('2020-02-03T19:38:33',  86, './TINT_3/LASSI/2020_02_03_19:38:33.fits'),
#           ('2020-02-03T19:38:33',  86, 'SCAN STARTING AT 58882 19:38:50'),
#           ('2020-02-03T19:38:33',  86, 'SCAN FINISHED AT 58882 19:39:10'),
#           ('2020-02-03T19:39:15',  87, './TINT_3/ActiveSurfaceMgr/2020_02_03_19:39:15.fits'),
#           ('2020-02-03T19:39:15',  87, 'SCAN STARTING AT 58882 19:39:17'),
#           ('2020-02-03T19:39:15',  87, 'SCAN FINISHED AT 58882 19:39:21'),
#           ('2020-02-03T19:39:28',  88, './TINT_3/LASSI/2020_02_03_19:39:28.fits'),
#           ('2020-02-03T19:39:28',  88, 'SCAN STARTING AT 58882 19:39:46'),
#           ('2020-02-03T19:39:28',  88, 'SCAN FINISHED AT 58882 19:40:05'),
# ...

# %%
hdu = fits.open("{0}/LASSI/2020_02_03_19:44:56.fits".format(datadir))
raw = hdu[1].data
raw_head = hdu[0].header

hdu = fits.open("{0}/LASSI/2020_02_03_19:44:56.zernike.fits".format(datadir))
zern = hdu[1].data
zern_head = hdu[0].header

hdu = fits.open("{0}/LASSI/2020_02_03_19:44:56.smoothed.fits".format(datadir))
smooth = hdu[1].data
smooth_head = hdu[0].header

# %%
plt.figure(dpi=150)
plt.subplot(121)
plt.imshow(zern['z'].reshape(512,512))
plt.subplot(122)
plt.imshow(smooth['z'].reshape(512,512))
# Out:
# <img src="data:image/png;base64,..." width="960">

# %%
raw_head
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                    8 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# ORIGIN  = 'NRAO Green Bank'    /
# INSTRUME= 'LASSI   '           / device or program of origin
# GBTMCVER= 'lassi   '           / telescope control software release
# FITSVER = '2.1     '           / FITS definition version for this device
# DATEBLD = 'DATEBLD  goes  here' / time program was linked
# SIMULATE=                    0 / Is the instrument in simulate mode?
# DATE-OBS= '2020-02-03T19:44:56' / Manager parameter startTime
# TIMESYS = 'UTC     '           / time scale specification for DATE-OBS
# ...

# %%
zern_head
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# HIERARCH center_az = 180.0
# HIERARCH center_el = 45.0
# FOV_AZ  =                180.0
# FOV_EL  =                 90.0
# HIERARCH scan_number = 1
# HIERARCH scan_time = '2020-01-28 14:19:24'
# PROJECT = 'TINT_200128'
# HIERARCH resolution = '31mm@100m'
# HIERARCH scan_mode = 'Speed   '
# HIERARCH tls_serial_number = 1851828
# HIERARCH sensitivity = 'Normal  '
# HIERARCH tls_tilt_compensator = 0
# HIERARCH mc_project = 'TINT_200128'
# MC_SCAN =                 6625
# REF     =                    F
# REFSCAN =                 6624
# N       =                  512

# %%
smooth_head
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# HIERARCH center_az = 180.0
# HIERARCH center_el = 45.0
# FOV_AZ  =                180.0
# FOV_EL  =                 90.0
# HIERARCH scan_number = 1
# HIERARCH scan_time = '2020-01-28 14:19:24'
# PROJECT = 'TINT_200128'
# HIERARCH resolution = '31mm@100m'
# HIERARCH scan_mode = 'Speed   '
# HIERARCH tls_serial_number = 1851828
# HIERARCH sensitivity = 'Normal  '
# HIERARCH tls_tilt_compensator = 0
# HIERARCH mc_project = 'TINT_200128'
# MC_SCAN =                 6625
# REF     =                    F
# REFSCAN =                 6624
# N       =                  512

# %%
hdu = fits.open("{0}/LASSI/2020_02_03_19:44:56.zernike.fits".format(datadir))

# %%
hdu[2].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   10 / length of dimension 1
# NAXIS2  =                   37 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                    2 / number of table fields
# TTYPE1  = 'coef    '
# TFORM1  = 'I       '
# TTYPE2  = 'value   '
# TFORM2  = 'D       '
