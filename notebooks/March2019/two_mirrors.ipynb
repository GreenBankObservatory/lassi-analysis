# %% [markdown]
# This notebook analyzes the March 27 scan where we can see both the primary and secondary mirrors of the GBT.

# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import pylab as plt

from astropy.stats import sigma_clip
# Make sure we can find lassi-analysis
import sys
sys.path.append('/home/scratch/psalas/LASSI/lassi-analysis_v2')

from gpus import smoothGPUParallel
from processPTX import processNewPTX
from plotting import scatter3dPlot, surfacePlot
from lassiAnalysis import processLeicaScan, maskLeicaData, regridXYZMasked

# %%
#raw_file = "/home/sandboxes/jbrandt/Telescope27Mar2019/CleanSubRef2.ptx"
raw_file = "/home/sandboxes/jbrandt/Telescope27Mar2019/Scan-2_10126x5028_20190327_1428_ReIoNo_ReMxNo_ColorNo_.ptx"
rot = 80.0
#ellipse = [-44., -6.5, 49.0, 49.0, 0]
ellipse = [-52., -8, 245.0, 245.0, 0]
xyz, _ = processNewPTX(raw_file, rot=rot, ellipse=ellipse)
# Out:
# ProcessNewPTXData with:  [-52.0, -8, 245.0, 245.0, 0]
# Picking 10000 random data points from a total of 19612779
# Skipped 5 non-data lines
# Skipped 10126 non-data lines
# Starting with 19602653 lines of data
# Filtered out 19159 points of 19602653 ( 0.10%) intensity equal to zero
# Now we have 19583494 lines of data
# neighborFilter reduces 19583494 points to 19243477 points (340017 filtered, 1.736243 %) using tol: 0.122000
# Now we have 19243477 lines of data
# Intensity: max= 1.00, min= 0.00, mean= 0.59, std= 0.25
# Elliptical fitler parameters:
# [-52.0, -8, 245.0, 245.0, 0]
# Filter removed 0 points outside the ellipse
# The ellipse has semi-major axis 245.00 m, semi-minor axis 245.00 m and angle 0.00 degrees
# Now we have 19243477 lines of data
# z - limit filtered out 14681372 points below -80.00 and above -10
# Rotating about Z by 80.00 degrees
# Now we have 4562105 lines of data
# Removed 0 points closer than 10.00 m from the scanner.
