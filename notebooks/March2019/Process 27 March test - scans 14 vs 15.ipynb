# %%
# %matplotlib notebook

# %%
from lassiAnalysis import processLeicaScan, processLeicaScanPair
file1 = "Scan-14.full.copy.ptx"
file2 = "Scan-15.full.copy.ptx"
fpath = "/home/scratch/psalas/LASSI/6Jun/"
import os
fn1 = os.path.join(fpath, file1)
fn2 = os.path.join(fpath, file2)
rot = -10.

# %%
# %%time
xy, diff = processLeicaScanPair(fn1, fn2, rFilter=True, rot=rot, fitZernikies=True)
# Out:
# Processing PTX file ...
# ProcessNewPTXData with:  -8.0 50.0 -10.0 47.0
# Picking 10000 random data points from a total of 12566340
# Skipped 2 non-data lines
# <img src="data:image/png;base64,..." width="639.85">
# <img src="data:image/png;base64,..." width="639.85">
# <img src="data:image/png;base64,..." width="639.85">
# Skipped 5099 non-data lines
# Starting with 12561241 lines of data
# Filtered out 22884 points of 12561241 ( 0.18%) intensity equal to zero
# Now we have 12538357 lines of data
# neighborFilter reduces 12538357 points to 11679848 points (858509 filtered, 6.847061 %) using tol: 0.122000
# Now we have 11679848 lines of data
# Intensity: max= 1.00, min= 0.00, mean= 0.76, std= 0.13
# radial limit filtered out 3581608 points outside radius 47.00
# Now we have 8098240 lines of data
# z - limit filtered out 12160 points below -80.00
# Rotating about Z by -10.00 degrees
# Now we have 8086080 lines of data
# <img src="data:image/png;base64,..." width="639.85">
# ...
