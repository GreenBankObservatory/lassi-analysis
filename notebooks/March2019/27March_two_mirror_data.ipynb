# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pylab as plt

from parabolas import loadLeicaData
from lassiAnalysis import maskLeicaData

# %%
n = 512
#fn = '/home/sandboxes/pmargani/LASSI/gpus/versions/gpu_smoothing/Scan-27_10126x2517_20190327_1333_ReIoNo_ReMxNo_ColorNo_.ptx.csv'
fn = '/home/scratch/psalas/LASSI/gpu_smoothing/Scan-27_10126x2517_20190327_1333_ReIoNo_ReMxNo_ColorNo_.ptx.csv'

# %%
ref_data = maskLeicaData(fn, n=n, guess=[60., 0., 0., -50., 0., 0.], radialMask=False)

# %%
x1, y1, z1 = ref_data['origData']
xr, yr, zr = ref_data['origMasked']
dzr = ref_data['fitResidual']
xpr, ypr, zpr = ref_data['parabolaFit']
xrr, yrr, zrr = ref_data['rotated']
cr = ref_data['parabolaFitCoeffs']

# %%
plt.figure()

plt.imshow(dzr)
# Out:
# <img src="data:image/png;base64,..." width="640">
