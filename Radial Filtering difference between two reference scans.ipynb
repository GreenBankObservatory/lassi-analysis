# %% [markdown]
# # Radial Fitlering Difference between two reference scans
# In which we demonstrate what a difference the radial filtering of the diff image makes when fitting for zernikies.

# %%
# %matplotlib notebook
from lassiAnalysis import processLeicaScanPair

# %% [markdown]
# ## Filter out the edges of the difference image
# And notice that the zernikies hardly ever get above an absolute value of 0.1.    Note that we don't have a ramp like we see in the Z4 data.  So, without the edges, this should be just random Z's to take into account the noise in our data(?).  Though z5 and z6 both have absolute values of .2.

# %%
# %%time
fn1 = "/home/sandboxes/jbrandt/Telescope27Mar2019/Clean9.ptx"
fn2 = "/home/sandboxes/jbrandt/Telescope27Mar2019/Clean10.ptx"
#par = [63.0250422585, 2.55958764, -0.40284763, -49.26607938]
par = [60.73303677,   2.36120724,   0.90942914, -49.24103739]
diffData = processLeicaScanPair(fn1, fn2, processed=True, rFilter=True)
# Out:
# Loading processed data from file: Clean9.ptx.processed.npz
# Loading processed data from file: Clean10.ptx.processed.npz
# Finding difference between scans ...
# xs1 dims -55.65319061279297 39.80973815917969 -7.921726226806641
# ys1 dims 2.284353494644165 97.03668212890625 49.66051781177521
# xs2 dims -55.686187744140625 39.785179138183594 -7.950504302978516
# ys2 dims 2.2843241691589355 97.03927612304688 49.661800146102905
# Center (-7.921726, 49.660518), Removing points close to edge: radius=45.500000
# radialReplace replaced 74408 points with nan
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# Fitting difference to zernikies ...
# <img src="data:image/png;base64,..." width="720">
# <img src="data:image/png;base64,..." width="720">
#                             Zernike Polynomials List
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Now don't filter out the edges
# And notice how much larger the zernike amplitudes become, up to really how powers too.

# %%
diffData = processLeicaScanPair(fn1, fn2, processed=True, rFilter=False)
# Out:
# Loading processed data from file: Clean9.ptx.processed.npz
# Loading processed data from file: Clean10.ptx.processed.npz
# Finding difference between scans ...
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# Fitting difference to zernikies ...
# <img src="data:image/png;base64,..." width="720">
# <img src="data:image/png;base64,..." width="720">
#                             Zernike Polynomials List
# ----------------------------------------------------------------------------------
# |   Z1  |   Z2  |   Z3  |   Z4  |   Z5  |   Z6  |   Z7  |   Z8  |   Z9  |  Z10  |
# ----------------------------------------------------------------------------------
# | 0.000 | 0.692 | 0.074 |-0.202 | 0.614 |-0.371 |-0.048 | 0.641 |-0.045 |-0.009 |
# ----------------------------------------------------------------------------------
# |  Z11  |  Z12  |  Z13  |  Z14  |  Z15  |  Z16  |  Z17  |  Z18  |  Z19  |  Z20  |
# ...
